# %% [markdown]
# # Основы комрьютерной графики, дополнительные задания

# %% [markdown]
# Гайсин Эдуард, 20.Б07-мм
#
# [Ссылка на исходные файлы](https://github.com/eduardgaisin/computer-graphics)

# %% [markdown]
# ## Задачи
#     С использованием изображения с камеры
#     1. Отразить изображение по правой границе
#     2. Найти контур изображения используя Лапласиан
#     3. Изменить яркость изображения

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# функция для получения кадра с камеры
def getFrame(camera):
    _, img = camera.read()
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

camera = cv2.VideoCapture(0)
img = getFrame(camera)
# img = cv2.resize(img, (img.shape[1] // 10, img.shape[0] // 10), interpolation=cv2.INTER_AREA)
plt.imshow(img)
plt.show()

# %% [markdown]
# # Отразить изображение по правой границе

# %%
def reflect_right(img):
    result = cv2.flip(img, 1)
    plt.imshow(result)
reflect_right(img)

# %% [markdown]
# # Найти контур изображения используя Лапласиан

# %%
def laplacian(img):
    img = cv2.blur(img, ksize=(3, 3))
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    result = cv2.Laplacian(img, cv2.CV_8U)
    plt.imshow(result, cmap="gray")
laplacian(img)

# %% [markdown]
# # Изменить яркость изображения

# %%
def brightness(img):
    result = cv2.convertScaleAbs(img, alpha=1, beta=100)
    plt.imshow(result)
brightness(img)
